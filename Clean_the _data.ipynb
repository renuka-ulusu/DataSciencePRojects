# %% [markdown]
# <a href="https://colab.research.google.com/github/renuka-ulusu/DataSciencePRojects/blob/main/Clean_the%20_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fg-data-profiling --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.3/400.3 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 59.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 32.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.8 MB/s eta 0:00:00

# %%
import pandas as pd
import numpy as np
import data_profiling
from data_profiling import ProfileReport
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-89954e22-52e2-4cbf-8202-94136046ff29" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89954e22-52e2-4cbf-8202-94136046ff29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("dataset_path")

# %% [markdown]
# A report on our data

# %%
profile=ProfileReport(df,title="Profiling Report",explorative=True)
profile.to_file('report.html')
files.download('report.html')

# %% [markdown]
# looking at the shape

# %%
df.shape

# %% [markdown]
# looking at the data types

# %%
df.dtypes

# %% [markdown]
# looking for the missing values

# %%
df.isnull().sum()

# %% [markdown]
# looking at the first 10 rows

# %%
df.head(10)

# %% [markdown]
# Standardize columns / column names

# %%
df.columns=(
    df.columns.str.replace(' ','_')
    .str.lower()
    .str.strip()
)

# %% [markdown]
# print percentages of missing values

# %%
missing = df.isnull().mean()*100
print(missing[missing>0].sort_values(ascending=False))

# %%
nu_dupes=df.duplicated
nu_dupes

# %%
df[df.duplicated(keep=False)].sort_values(by=list(df.columns)).head(10)

# %%
df=df.drop_duplicates

# %%
df.shape()

# %% [markdown]
# filling missing values by columns
# Numerical -> median
# Categorical -> unknown

# %%
df=df.copy()
for col in ['total_amount']:
  df[col]=df[col].fillna(df[col].median())
categorical_cols= ['customer_id','country','category']
df[categorical_cols]=df[categorical_cols].fillna('Unknown')

# %%
print(df.isnull().sum()[df.isnull().sum()>0])

# %% [markdown]
#  standardize text messy data

# %%
for col in ['category','status','country']:
  df[col]=df[col].str.strip().str.lower()
category_map={
    'electronics':'Electronics',
    'clothing':'Clothing',
    'home & garden':'Home & Garden',
    'home and garden': 'Home & Garden',
    'furniture':'Furniture'
    'unknown':'Unknown'
}
df['category']=df['category'].map(category_map).fillna(df['category'])

status_map={
    'delivered':'Delivered',
    'shipped':'Shipped',
    'pending':'Pending',
    'cancelled':'Cancelled',
    'unknown':'Unknown
}
df['status']=df['status'].map(status_map).fillna(df['status'])

country_map={
    'United states':'United States',
    'canada':'Canada',
    'uk':'United Kingdom',
    'unknown':'Unknown
}
df['country']=df['country'].map(country_map).fillna(df['country'])

# %%
df.head(10)

# %%
df['unit_price']=df['unit_price'].astype(str).str.replace('$','',regex=False).str.strip()
df['unit_price']=pd.to_numeric(df['unit_price'],errors='coerce')

# %%
df.head(10)

# %%
bool_map={
    'Yes':True,'yes':True,'Y':True,'y':True,
    'No':False,'no':False,'N':False,'n':False
}
df['is_returned']=df['is_returned'].map(bool_map).fillna(df[False])

# %%
df['order_date']=pd.to_datetime(df['order_date'],dayfirst=False,errors=coerce)
failed=df['order_date'].isnull().sum()
df.head()
